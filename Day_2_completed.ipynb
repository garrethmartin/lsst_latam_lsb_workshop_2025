# %% [raw]
# # run for colab - doesn't completely work at the moment
# !git clone https://github.com/garrethmartin/lsst_latam_lsb_workshop_2025.git
# %cd lsst_latam_lsb_workshop_2025
#
# from setup_env import setup_environment
# setup_environment('environment_colab.yml')
#
# from google.colab import output
# output.enable_custom_widget_manager()
#
# %matplotlib inline
# from fits_mask_tools import FitsViewer, BackgroundInteractive, MaskPainter, BinnedFitsViewer, ImageCropper
# import matplotlib.pyplot as plt
# import numpy as np
# import h5py

# %%
# run for local jupyter notebook
# %matplotlib notebook
from fits_mask_tools import MaskPainter, BinnedFitsViewer, FitsViewer
from galaxylib import GalaxyLibrary
import matplotlib.pyplot as plt
import numpy as np
import h5py

# %% [markdown]
# Load the Saved State
# Restore the configuration and image saved at the end of Day 1.
# - Feel free to re-adjust the binning or image scaling using the sliders

# %%
rebinned_fv = BinnedFitsViewer.load_state()
# Out:
# <img src="data:image/png;base64,..." width="800">
# interactive(children=(Dropdown(description='stretch', index=3, options=('linear', 'log', 'sqrt', 'asinh'), val…
# IntSlider(value=1, description='Binning', max=20, min=1)

# %% [markdown]
# ## Types of Tidal Features in Galaxies
#
# When studying low-surface-brightness structures around galaxies, it can help to distinguish between different types of tidal features. These features provide insight into the galaxy's interaction history and the dynamics of its stellar halo. Here we describe the main classes:
#
# ### 1. Stellar Streams
# Stellar streams are elongated structures composed of stars orbiting the host galaxy. Their appearance depends on the viewing angle and the orbit of the progenitor system; they can appear as ellipses, spirals, or straight lines. Each stream represents a distinct event of material being stripped from a satellite galaxy. For example, an image might show a single clear stream or multiple independent streams around the same galaxy due to multiple satellites.
#
# ![Stellar stream](./example_images/streams.png)
#
# ### 2. Tidal Tails
# Tidal tails are extended features that originate from material ejected during strong interactions between galaxies of comparable mass. Unlike stellar streams, which are often formed gradually, tidal tails consist of stars and gas that have been unbound from a galaxy during a close encounter or merger. They trace the path of recently stripped material and can extend over tens of kiloparsecs.
#
# ![Tidal tails](./example_images/tails.png)
#
# ### 3. Plumes or Asymmetric Stellar Halos
# Plumes are diffuse, low-surface-brightness structures in the outer regions of galaxies that do not form well-defined streams or tails. They can include irregular, asymmetric features in the stellar halo, often reflecting past accretion or minor mergers. Unlike streams or tails, plumes have no clear geometry.
#
# ![Plumes](./example_images/plumes.png)
#
# ### 4. Shells
# Shells appear as concentric, arc-like or ring-like structures around a galaxy. These radial features usually do not cross one another and are thought to form from phase-wrapped material during minor mergers. Shells provide a record of past accretion events, often from smaller companions.
#
# ![Shells](./example_images/shells.png)
#
# ### 5. Tidal Bridges
# A tidal bridge is a specific type of tidal tail that connects two interacting galaxies. Bridges are formed when material is pulled out during a high-mass-ratio encounter, linking the two galaxies. Unlike isolated tidal tails, which may extend into the halo, bridges physically connect the interacting systems.
#
# ![Tidal bridges](./example_images/bridge.png)
#
# ### 6. Merger Remnants
# Merger remnants are galaxies that show strong morphological disturbances resulting from a recent coalescence of two progenitors along with extended diffuse emission such as tidal tails, shells or other diffise debris.
#
# ![Merger remnants](./example_images/merger_remnant.png)
#
# ---
#
# By carefully identifying and classifying these tidal features in images, we can reconstruct some idea of the interaction history of galaxies and gain insight into the hierarchical assembly of halos.

# %% [markdown]
# ## Instructions for Using the Mask Painter
#
# **Initial setup:** Click on the image to create a zoom crop around the region you want to mask. The zoomed-in area will appear in the viewer.
#
# **Painting masks:**
#
# - Click and drag the mouse over features you want to mask.
#
# - Adjust the brush size using the slider to cover larger or smaller regions.
#
# - While painting, the zoom slider is disabled.
#
# **Committing a mask:** When you have finished painting a mask in the current zoom region, press the **`next mask`** button. This commits the current mask and allows you to start painting a new feature.
#
# **Resetting the view:** To return to the full image at any time, press Return to original.
#
# *Note: Any uncommitted mask in the zoomed region will be discarded.*
#
# **Saving all masks:**
#
# Once you have painted and committed all regions of interest, press **`save masks`**. This will write all masks and their associated cutouts to ./masks/masks_data.hdf5.
#
# **Tips:**
#
# - Make sure to commit each mask before moving to a new region.
#
# - Use the zoom slider to focus on small details or larger regions as needed.
#
# - The overlay shows the masks in semi-transparent colours so you can see what has already been masked.
#
# ### Exercise: Identifying tidal features
#
# Use the Mask Painter tool to identify and mask low-surface-brightness tidal features in the image.
#
# - Examine the image carefully to locate features such as **stellar streams, tidal tails, plumes, shells, bridges,** and **merger remnants**.
# - For each feature:
#   - Zoom in on a region using the zoom slider.
#   - Select the feature type from the dropdown menu
#   - Paint around the feature with the brush tool, adjusting the size as needed.
#   - Press **`Next mask`** to commit the painted mask before moving to a new feature.
#   - Make a note of the type of each feature.
# - Continue until you have masked all visible tidal structures in the image.
# - When finished, press **`Save masks`** to write all masks and associated cutouts to `./masks/masks_data.hdf5`.
#
# **Goal:** Produce a set of masks for all the tidal features you can identify, which can be used for further analysis or photometry.

# %%
painter = MaskPainter(rebinned_fv)
# Out:
# <img src="data:image/png;base64,..." width="800">
# HBox(children=(Button(button_style='info', description='next mask', style=ButtonStyle()), Button(button_style=…
# MaskPainter ready — click to create a zoom crop, paint, then commit.
# Zoomed to size=60 centred on (171, 191).
# Zoomed to size=70 centred on (171, 191).
# Zoomed to size=80 centred on (171, 191).
# Zoomed to size=90 centred on (171, 191).
# Zoomed to size=100 centred on (171, 191).
# Zoomed to size=110 centred on (171, 191).
# Zoomed to size=120 centred on (171, 191).
# Zoomed to size=130 centred on (171, 191).
# Zoomed to size=140 centred on (171, 191).
# Zoomed to size=150 centred on (171, 191).
# Zoomed to size=160 centred on (171, 191).
# Committed mask #1.
# Committed mask #2.
# Committed mask #3.
# Committed mask #4.
# Committed mask #5.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #6.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Zoomed to size=150 centred on (78, 1045).
# Zoomed to size=140 centred on (78, 1045).
# Zoomed to size=130 centred on (78, 1045).
# Zoomed to size=120 centred on (78, 1045).
# Zoomed to size=110 centred on (78, 1045).
# Zoomed to size=100 centred on (78, 1045).
# Zoomed to size=90 centred on (78, 1045).
# Zoomed to size=80 centred on (78, 1045).
# Zoomed to size=90 centred on (78, 1045).
# Zoomed to size=100 centred on (78, 1045).
# Zoomed to size=110 centred on (78, 1045).
# Zoomed to size=120 centred on (78, 1045).
# Zoomed to size=130 centred on (78, 1045).
# Zoomed to size=140 centred on (78, 1045).
# Committed mask #7.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #8.
# Committed mask #9.
# Committed mask #10.
# Returned to full image (local mask discarded).
# Committed mask #11.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #12.
# Committed mask #13.
# Committed mask #14.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #15.
# Committed mask #16.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #17.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #18.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #19.
# Returned to full image (local mask discarded).
# Committed mask #20.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #21.
# Committed mask #22.
# Returned to full image (local mask discarded).
# Committed mask #23.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #24.
# Committed mask #25.
# Committed mask #26.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #27.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #28.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #29.
# Returned to full image (local mask discarded).
# Committed mask #30.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #31.
# Returned to full image (local mask discarded).
# Committed mask #32.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #33.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #34.
# Committed mask #35.
# Committed mask #36.
# Committed mask #37.
# Committed mask #38.
# Committed mask #39.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #40.
# Committed mask #41.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #42.
# Committed mask #43.
# Returned to full image (local mask discarded).
# Committed mask #44.
# Returned to full image (local mask discarded).
# Committed mask #45.
# Returned to full image (local mask discarded).
# Committed mask #46.
# Committed mask #47.
# Committed mask #48.
# Committed mask #49.
# Committed mask #50.
# Committed mask #51.
# Committed mask #52.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #53.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #54.
# Committed mask #55.
# Committed mask #56.
# Returned to full image (local mask discarded).
# Committed mask #57.
# Committed mask #58.
# Committed mask #59.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #60.
# Committed mask #61.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #62.
# Committed mask #63.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #64.
# Committed mask #65.
# Committed mask #66.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #67.
# Committed mask #68.
# Committed mask #69.
# Committed mask #70.
# Returned to full image (local mask discarded).
# Committed mask #71.
# Committed mask #72.
# Committed mask #73.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #74.
# Committed mask #75.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Zoomed to size=130 centred on (879, 311).
# Zoomed to size=120 centred on (879, 311).
# Zoomed to size=110 centred on (879, 311).
# Zoomed to size=120 centred on (879, 311).
# Zoomed to size=130 centred on (879, 311).
# Zoomed to size=140 centred on (879, 311).
# Zoomed to size=150 centred on (879, 311).
# Zoomed to size=160 centred on (879, 311).
# Zoomed to size=170 centred on (879, 311).
# Zoomed to size=180 centred on (879, 311).
# Zoomed to size=200 centred on (879, 311).
# Zoomed to size=210 centred on (879, 311).
# Zoomed to size=220 centred on (879, 311).
# Zoomed to size=230 centred on (879, 311).
# Zoomed to size=240 centred on (879, 311).
# Zoomed to size=250 centred on (879, 311).
# Zoomed to size=260 centred on (879, 311).
# Zoomed to size=270 centred on (879, 311).
# Zoomed to size=280 centred on (879, 311).
# Zoomed to size=270 centred on (879, 311).
# Zoomed to size=280 centred on (879, 311).
# Zoomed to size=290 centred on (879, 311).
# Zoomed to size=300 centred on (879, 311).
# Zoomed to size=310 centred on (879, 311).
# Zoomed to size=320 centred on (879, 311).
# Committed mask #76.
# Returned to full image (local mask discarded).
# Zoomed to size=680 centred on (884, 333).
# Zoomed to size=260 centred on (884, 333).
# Zoomed to size=1000 centred on (884, 333).
# Zoomed to size=670 centred on (884, 333).
# Zoomed to size=1000 centred on (884, 333).
# Zoomed to size=50 centred on (884, 333).
# Zoomed to size=300 centred on (884, 333).
# Zoomed to size=450 centred on (884, 333).
# Zoomed to size=390 centred on (884, 333).
# Returned to full image (local mask discarded).
# Zoomed to size=380 centred on (1003, 179).
# Zoomed to size=370 centred on (1003, 179).
# Zoomed to size=360 centred on (1003, 179).
# Zoomed to size=350 centred on (1003, 179).
# Zoomed to size=330 centred on (1003, 179).
# Zoomed to size=320 centred on (1003, 179).
# Zoomed to size=300 centred on (1003, 179).
# Zoomed to size=290 centred on (1003, 179).
# Zoomed to size=270 centred on (1003, 179).
# Zoomed to size=260 centred on (1003, 179).
# Zoomed to size=250 centred on (1003, 179).
# Zoomed to size=240 centred on (1003, 179).
# Zoomed to size=230 centred on (1003, 179).
# Zoomed to size=220 centred on (1003, 179).
# Zoomed to size=210 centred on (1003, 179).
# Zoomed to size=200 centred on (1003, 179).
# Zoomed to size=190 centred on (1003, 179).
# Zoomed to size=180 centred on (1003, 179).
# Zoomed to size=170 centred on (1003, 179).
# Zoomed to size=160 centred on (1003, 179).
# Zoomed to size=150 centred on (1003, 179).
# Zoomed to size=140 centred on (1003, 179).
# Zoomed to size=130 centred on (1003, 179).
# Zoomed to size=120 centred on (1003, 179).
# Zoomed to size=110 centred on (1003, 179).
# Zoomed to size=100 centred on (1003, 179).
# Zoomed to size=90 centred on (1003, 179).
# Zoomed to size=80 centred on (1003, 179).
# Zoomed to size=90 centred on (1003, 179).
# Zoomed to size=100 centred on (1003, 179).
# Zoomed to size=110 centred on (1003, 179).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #77.
# Committed mask #78.
# Returned to full image (local mask discarded).
# Committed mask #79.
# Committed mask #80.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #81.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #82.
# Committed mask #83.
# Committed mask #84.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #85.
# Returned to full image (local mask discarded).
# Committed mask #86.
# Committed mask #87.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #88.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #89.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #90.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #91.
# Zoomed to size=100 centred on (985, 897).
# Zoomed to size=90 centred on (985, 897).
# Zoomed to size=100 centred on (985, 897).
# Zoomed to size=110 centred on (985, 897).
# Zoomed to size=120 centred on (985, 897).
# Zoomed to size=130 centred on (985, 897).
# Zoomed to size=140 centred on (985, 897).
# Zoomed to size=150 centred on (985, 897).
# Zoomed to size=160 centred on (985, 897).
# Zoomed to size=170 centred on (985, 897).
# Zoomed to size=180 centred on (985, 897).
# Zoomed to size=190 centred on (985, 897).
# Zoomed to size=180 centred on (985, 897).
# Zoomed to size=170 centred on (985, 897).
# Zoomed to size=160 centred on (985, 897).
# Zoomed to size=150 centred on (985, 897).
# Zoomed to size=160 centred on (985, 897).
# Returned to full image (local mask discarded).
# Committed mask #92.
# Committed mask #93.
# Committed mask #94.
# Committed mask #95.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #96.
# Committed mask #97.
# Committed mask #98.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Committed mask #99.
# Returned to full image (local mask discarded).
# Returned to full image (local mask discarded).
# Saved 99 masks with associated cutouts to ./masks/masks_data.hdf5

# %% [markdown]
# After saving, use the `plot_saved_masks()` function to visualise the masked regions

# %% [markdown]
# ## Exercise: Visualising your saved masks
#
# **Aim.** Inspect the masks you have painted and saved.
#
# ### Steps
#
# 1. Use `MaskPainter.plot_saved_masks('./masks/masks_data.hdf5')` to display all saved masks.

# %%
dict_masks = MaskPainter.plot_saved_masks('./masks/masks_data.hdf5')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# 2. Examine each cutout and overplotted mask:
#    - Confirm the mask covers the intended tidal feature fully.
#    - Check that the contour correctly outlines the masked region.
#    - Check that the feature label corresponds to the expected type.

# %% [markdown]
# ### Exercise: Measuring the Surface Brightness of Tidal Features
#
# In this exercise, you will use the masks you created to quantify the brightness of tidal features.
#
# - For each highlighted feature in your mask set:
#   - Compute the average surface brightness within the painted region.
#   - We can use the following conversions:

# %%
FLUXMAG0 = 63095734448.0194  # counts -> magnitudes
IMAGE_SCALE = 0.2 * rebinned_fv.bin_slider.value  # arcsec / pixel

# %% [markdown]
# *Note on image scale:*
#
#   Since we have rebinned the image, the pixel size is effectively larger than the original `IMAGE_SCALE`:
# $$
# \text{IMAGE_SCALE} = 0.2 \times \text{bin_factor} \quad [\text{arcsec/pixel}]
# $$
#
# Given a masked image of a tidal feature, we can define the **mean** and **median** surface brightness in units of mag/arcsec² as follows.
#
# Let $F_i$ be the counts in pixel $i$ of the masked region, and $\text{pixscale}$ the pixel scale in arcsec/pixel. Also, let $\mathrm{FLUXMAG0}$ be the zero-point flux corresponding to 0 mag.
#
#
# 1. Modify the code below to:
#  - convert total counts in ADU and area in pixels for each mask to calculate mean surface brightness in  mag / arcsec$^{2}$
#  $$
# \langle \mu \rangle = -2.5 \log_{10} \left( \frac{ \sum_{i=1}^{N} F_i }{ N \, \mathrm{pixscale}^2 \, \mathrm{FLUXMAG0} } \right)
# $$
#  - calculate the median surface brightness per pixel
#  $$
# \mu_{\rm med} = -2.5 \log_{10} \left( \frac{ \mathrm{median}(F_i) }{ \mathrm{pixscale}^2 \, \mathrm{FLUXMAG0} } \right)
# $$
#
# - The **mean** accounts for all pixels, so bright spots within the feature (e.g., compact clumps) can skew it higher.
# - The **median** is less sensitive to outliers, reflecting the typical surface brightness of the majority of the feature.

# %%
mean_sb = []
median_sb = []
feature_label = []
for mask_name, info in dict_masks.items():
    
    label = info['feature_label']
    img_masked = info['masked_data']
    
    total_counts = np.ma.sum(img_masked)
    area_pixels = np.count_nonzero(img_masked.mask)
            
    print(f"{mask_name}:")
    print(f"  Label: {label}")
    print(f"  Area (pixels): {area_pixels}")
    print(f"  Total counts: {total_counts:.3e}")
    print("-" * 40)
    
    feature_label.append(label)

    
    # ADD YOUR CODE HERE
    
    median_counts = np.ma.median(img_masked)
    
    mean_sb.append(-2.5 * np.log10(total_counts / (FLUXMAG0 * area_pixels * IMAGE_SCALE**2)))
    median_sb.append(-2.5 * np.log10(median_counts / (FLUXMAG0 * IMAGE_SCALE**2)))
    
feature_label = np.asarray(feature_label)
mean_sb = np.asarray(mean_sb)
median_sb = np.asarray(median_sb)
# Out:
# mask_0000:
#   Label: Stellar Stream
#   Area (pixels): 761
#   Total counts: 1.016e+03
# ----------------------------------------
# mask_0001:
#   Label: Stellar Stream
#   Area (pixels): 812
#   Total counts: 1.108e+03
# ----------------------------------------
# mask_0002:
#   Label: Stellar Stream
#   Area (pixels): 337
#   Total counts: 1.119e+03
# ----------------------------------------
# mask_0003:
#   Label: Stellar Stream
#   Area (pixels): 276
#   Total counts: 6.416e+02
# ----------------------------------------
# mask_0004:
#   Label: Tidal Tail
#   Area (pixels): 85
#   Total counts: 5.033e+01
# ----------------------------------------
# mask_0005:
#   Label: Plume
#   Area (pixels): 38
#   Total counts: 2.794e+01
# ----------------------------------------
# mask_0006:
#   Label: Plume
#   Area (pixels): 34
#   Total counts: 4.272e+01
# ----------------------------------------
# mask_0007:
#   Label: Stellar Stream
#   Area (pixels): 21
#   Total counts: 4.740e+01
# ----------------------------------------
# mask_0008:
#   Label: Plume
#   Area (pixels): 136
#   Total counts: 1.112e+02
# ----------------------------------------
# mask_0009:
#   Label: Plume
#   Area (pixels): 135
#   Total counts: 4.367e+01
# ----------------------------------------
# mask_0010:
#   Label: Merger Remnant
#   Area (pixels): 345
#   Total counts: 1.614e+03
# ----------------------------------------
# mask_0011:
#   Label: Merger Remnant
#   Area (pixels): 374
#   Total counts: 2.036e+03
# ----------------------------------------
# mask_0012:
#   Label: Tidal Tail
#   Area (pixels): 97
#   Total counts: 3.138e+02
# ----------------------------------------
# mask_0013:
#   Label: Tidal Tail
#   Area (pixels): 104
#   Total counts: 2.810e+02
# ----------------------------------------
# mask_0014:
#   Label: Tidal Tail
#   Area (pixels): 29
#   Total counts: 1.187e+01
# ----------------------------------------
# mask_0015:
#   Label: Tidal Tail
#   Area (pixels): 34
#   Total counts: 1.707e+01
# ----------------------------------------
# mask_0016:
#   Label: Tidal Tail
#   Area (pixels): 12
#   Total counts: 1.507e+01
# ----------------------------------------
# mask_0017:
#   Label: Stellar Stream
#   Area (pixels): 45
#   Total counts: 2.454e+01
# ----------------------------------------
# mask_0018:
#   Label: Merger Remnant
#   Area (pixels): 583
#   Total counts: 1.357e+03
# ----------------------------------------
# mask_0019:
#   Label: Tidal Tail
#   Area (pixels): 56
#   Total counts: 1.450e+02
# ----------------------------------------
# mask_0020:
#   Label: Tidal Tail
#   Area (pixels): 27
#   Total counts: 7.830e+00
# ----------------------------------------
# mask_0021:
#   Label: Plume
#   Area (pixels): 4
#   Total counts: 1.067e+01
# ----------------------------------------
# mask_0022:
#   Label: Tidal Tail
#   Area (pixels): 54
#   Total counts: 4.578e+01
# ----------------------------------------
# mask_0023:
#   Label: Tidal Tail
#   Area (pixels): 272
#   Total counts: 4.739e+01
# ----------------------------------------
# mask_0024:
#   Label: Stellar Stream
#   Area (pixels): 41
#   Total counts: 4.781e+01
# ----------------------------------------
# mask_0025:
#   Label: Plume
#   Area (pixels): 24
#   Total counts: 1.951e+02
# ----------------------------------------
# mask_0026:
#   Label: Merger Remnant
#   Area (pixels): 65
#   Total counts: 1.310e+02
# ----------------------------------------
# mask_0027:
#   Label: Stellar Stream
#   Area (pixels): 56
#   Total counts: 1.193e+01
# ----------------------------------------
# mask_0028:
#   Label: Tidal Tail
#   Area (pixels): 175
#   Total counts: 6.787e+01
# ----------------------------------------
# mask_0029:
#   Label: Merger Remnant
#   Area (pixels): 67
#   Total counts: 9.607e+01
# ----------------------------------------
# mask_0030:
#   Label: Plume
#   Area (pixels): 589
#   Total counts: 2.939e+02
# ----------------------------------------
# mask_0031:
#   Label: Plume
#   Area (pixels): 238
#   Total counts: 1.230e+02
# ----------------------------------------
# mask_0032:
#   Label: Stellar Stream
#   Area (pixels): 343
#   Total counts: 1.115e+01
# ----------------------------------------
# mask_0033:
#   Label: Tidal Tail
#   Area (pixels): 83
#   Total counts: 3.751e+01
# ----------------------------------------
# mask_0034:
#   Label: Tidal Tail
#   Area (pixels): 62
#   Total counts: 9.974e+01
# ----------------------------------------
# mask_0035:
#   Label: Tidal Tail
#   Area (pixels): 91
#   Total counts: 1.017e+02
# ----------------------------------------
# mask_0036:
#   Label: Tidal Tail
#   Area (pixels): 66
#   Total counts: 4.865e+01
# ----------------------------------------
# mask_0037:
#   Label: Stellar Stream
#   Area (pixels): 25
#   Total counts: 5.088e+00
# ----------------------------------------
# mask_0038:
#   Label: Plume
#   Area (pixels): 13
#   Total counts: 1.148e+01
# ----------------------------------------
# mask_0039:
#   Label: Tidal Tail
#   Area (pixels): 16
#   Total counts: 2.104e+01
# ----------------------------------------
# mask_0040:
#   Label: Merger Remnant
#   Area (pixels): 97
#   Total counts: 1.126e+02
# ----------------------------------------
# mask_0041:
#   Label: Stellar Stream
#   Area (pixels): 472
#   Total counts: 2.525e+01
# ----------------------------------------
# mask_0042:
#   Label: Plume
#   Area (pixels): 29
#   Total counts: 1.192e+01
# ----------------------------------------
# mask_0043:
#   Label: Tidal Tail
#   Area (pixels): 51
#   Total counts: 4.024e+01
# ----------------------------------------
# mask_0044:
#   Label: Tidal Bridge
#   Area (pixels): 19
#   Total counts: 8.612e+00
# ----------------------------------------
# mask_0045:
#   Label: Shell
#   Area (pixels): 57
#   Total counts: 4.144e+01
# ----------------------------------------
# mask_0046:
#   Label: Shell
#   Area (pixels): 161
#   Total counts: 2.709e+01
# ----------------------------------------
# mask_0047:
#   Label: Shell
#   Area (pixels): 74
#   Total counts: 4.647e+01
# ----------------------------------------
# mask_0048:
#   Label: Shell
#   Area (pixels): 69
#   Total counts: 9.199e+01
# ----------------------------------------
# mask_0049:
#   Label: Plume
#   Area (pixels): 36
#   Total counts: 1.064e+01
# ----------------------------------------
# mask_0050:
#   Label: Plume
#   Area (pixels): 279
#   Total counts: 1.370e+01
# ----------------------------------------
# mask_0051:
#   Label: Stellar Stream
#   Area (pixels): 71
#   Total counts: 6.586e+00
# ----------------------------------------
# mask_0052:
#   Label: Merger Remnant
#   Area (pixels): 91
#   Total counts: 1.486e+02
# ----------------------------------------
# mask_0053:
#   Label: Tidal Tail
#   Area (pixels): 17
#   Total counts: 1.873e+01
# ----------------------------------------
# mask_0054:
#   Label: Plume
#   Area (pixels): 12
#   Total counts: 2.966e+01
# ----------------------------------------
# mask_0055:
#   Label: Plume
#   Area (pixels): 258
#   Total counts: 1.542e+02
# ----------------------------------------
# mask_0056:
#   Label: Merger Remnant
#   Area (pixels): 61
#   Total counts: 2.315e+02
# ----------------------------------------
# mask_0057:
#   Label: Plume
#   Area (pixels): 440
#   Total counts: 7.598e+01
# ----------------------------------------
# mask_0058:
#   Label: Plume
#   Area (pixels): 111
#   Total counts: 5.010e+01
# ----------------------------------------
# mask_0059:
#   Label: Plume
#   Area (pixels): 226
#   Total counts: 6.793e+02
# ----------------------------------------
# mask_0060:
#   Label: Tidal Tail
#   Area (pixels): 44
#   Total counts: 1.859e+01
# ----------------------------------------
# mask_0061:
#   Label: Merger Remnant
#   Area (pixels): 41
#   Total counts: 1.025e+02
# ----------------------------------------
# mask_0062:
#   Label: Plume
#   Area (pixels): 25
#   Total counts: 4.677e+01
# ----------------------------------------
# mask_0063:
#   Label: Plume
#   Area (pixels): 21
#   Total counts: 8.651e+00
# ----------------------------------------
# mask_0064:
#   Label: Plume
#   Area (pixels): 101
#   Total counts: 1.544e+01
# ----------------------------------------
# mask_0065:
#   Label: Plume
#   Area (pixels): 77
#   Total counts: 2.505e+01
# ----------------------------------------
# mask_0066:
#   Label: Shell
#   Area (pixels): 526
#   Total counts: 4.340e+02
# ----------------------------------------
# mask_0067:
#   Label: Shell
#   Area (pixels): 887
#   Total counts: 7.818e+02
# ----------------------------------------
# mask_0068:
#   Label: Shell
#   Area (pixels): 1215
#   Total counts: 8.564e+02
# ----------------------------------------
# mask_0069:
#   Label: Shell
#   Area (pixels): 1985
#   Total counts: 3.467e+02
# ----------------------------------------
# mask_0070:
#   Label: Stellar Stream
#   Area (pixels): 586
#   Total counts: 4.525e+01
# ----------------------------------------
# mask_0071:
#   Label: Plume
#   Area (pixels): 99
#   Total counts: 1.733e+02
# ----------------------------------------
# mask_0072:
#   Label: Tidal Tail
#   Area (pixels): 50
#   Total counts: 8.100e+01
# ----------------------------------------
# mask_0073:
#   Label: Merger Remnant
#   Area (pixels): 315
#   Total counts: 9.552e+02
# ----------------------------------------
# mask_0074:
#   Label: Stellar Stream
#   Area (pixels): 51
#   Total counts: 1.156e+02
# ----------------------------------------
# mask_0075:
#   Label: Stellar Stream
#   Area (pixels): 4770
#   Total counts: 2.522e+02
# ----------------------------------------
# mask_0076:
#   Label: Stellar Stream
#   Area (pixels): 154
#   Total counts: 4.289e+01
# ----------------------------------------
# mask_0077:
#   Label: Stellar Stream
#   Area (pixels): 131
#   Total counts: 4.130e+01
# ----------------------------------------
# mask_0078:
#   Label: Plume
#   Area (pixels): 464
#   Total counts: 1.634e+02
# ----------------------------------------
# mask_0079:
#   Label: Plume
#   Area (pixels): 360
#   Total counts: 1.450e+02
# ----------------------------------------
# mask_0080:
#   Label: Merger Remnant
#   Area (pixels): 73
#   Total counts: 1.410e+02
# ----------------------------------------
# mask_0081:
#   Label: Tidal Tail
#   Area (pixels): 39
#   Total counts: 2.234e+01
# ----------------------------------------
# mask_0082:
#   Label: Tidal Tail
#   Area (pixels): 74
#   Total counts: 7.059e+01
# ----------------------------------------
# mask_0083:
#   Label: Tidal Bridge
#   Area (pixels): 26
#   Total counts: 4.356e+01
# ----------------------------------------
# mask_0084:
#   Label: Tidal Tail
#   Area (pixels): 12
#   Total counts: 3.280e+00
# ----------------------------------------
# mask_0085:
#   Label: Tidal Tail
#   Area (pixels): 90
#   Total counts: 7.376e+01
# ----------------------------------------
# mask_0086:
#   Label: Plume
#   Area (pixels): 36
#   Total counts: 3.475e+01
# ----------------------------------------
# mask_0087:
#   Label: Plume
#   Area (pixels): 155
#   Total counts: 7.742e+01
# ----------------------------------------
# mask_0088:
#   Label: Tidal Tail
#   Area (pixels): 255
#   Total counts: 1.899e+01
# ----------------------------------------
# mask_0089:
#   Label: Plume
#   Area (pixels): 76
#   Total counts: 1.431e+01
# ----------------------------------------
# mask_0090:
#   Label: Plume
#   Area (pixels): 22
#   Total counts: 6.350e+00
# ----------------------------------------
# mask_0091:
#   Label: Stellar Stream
#   Area (pixels): 376
#   Total counts: 6.430e+00
# ----------------------------------------
# mask_0092:
#   Label: Stellar Stream
#   Area (pixels): 441
#   Total counts: 1.726e+01
# ----------------------------------------
# mask_0093:
#   Label: Tidal Tail
#   Area (pixels): 43
#   Total counts: 7.900e+00
# ----------------------------------------
# mask_0094:
#   Label: Stellar Stream
#   Area (pixels): 316
#   Total counts: 3.851e+01
# ----------------------------------------
# mask_0095:
#   Label: Shell
#   Area (pixels): 200
#   Total counts: 1.626e+01
# ----------------------------------------
# mask_0096:
#   Label: Shell
#   Area (pixels): 61
#   Total counts: 1.497e+01
# ----------------------------------------
# mask_0097:
#   Label: Shell
#   Area (pixels): 117
#   Total counts: 6.243e+00
# ----------------------------------------
# mask_0098:
#   Label: Merger Remnant
#   Area (pixels): 192
#   Total counts: 3.701e+02
# ----------------------------------------

# %% [markdown]
# 2. Once you have computed the median surface brightness for each masked tidal feature, we can visualise the distribution to identify the faintest structures detectable in the image.
#
# - **Plot a histogram** of the mean and median surface brightnesses:

# %%
plt.figure()

plt.hist(median_sb, range=[25,32], bins=20, color='skyblue', edgecolor='black')
plt.gca().invert_xaxis()  # fainter on the left
plt.xlabel("Median Surface Brightness [mag/arcsec$^{2}$]")
plt.ylabel("Number of Features")
plt.title("Distribution of Tidal Feature Surface Brightnesses")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.1666666666666">

# %%
plt.figure()

plt.hist(mean_sb, range=[25,32], bins=20, color='skyblue', edgecolor='black')
plt.gca().invert_xaxis()  # fainter on the left
plt.xlabel("Median Surface Brightness [mag/arcsec$^{2}$]")
plt.ylabel("Number of Features")
plt.title("Distribution of Tidal Feature Surface Brightnesses")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.1666666666666">

# %%
plt.figure()
plt.scatter(mean_sb, median_sb, color='k')
plt.plot([24,31],[24,31], ls='--', color='0.5', lw=3)

plt.xlabel('mean'); plt.ylabel('median')
# Out:
# <img src="data:image/png;base64,..." width="640.1666666666666">
# Text(0, 0.5, 'median')

# %% [markdown]
# Examine the histogram.
#
# - What is the **range of surface brightnesses** across the feature.
# - What are the **faintest regions** that are still detectable above the background noise.
# - Is there a significant offset between the mean and median values.
#
# By examining the histogram:
#
# - The **peak** indicates the most common surface brightness within the feature.
# - The **faint tail** shows the lowest surface brightness regions that are still measurable.
# - Comparing histograms for different features can highlight which are easier to detect and which are likely lost in the noise.

# %% [markdown]
# 3. Visually and quantitatively compare the median surface-brightness values for each tidal-feature class you labelled.
#
# You should already have two parallel arrays:
# - `median_sb` — median surface brightness of each feature (mag/arcsec^{2}),
# - `labels` — class label for each feature.
#
# - Plot
#   - Use the code below to overplot histograms for each label on the same axes
#   - **optional** Plot cumulative distribution functions (CDFs) for each class on a second axis

# %%
unique_labels = np.unique(feature_label)

for lab in unique_labels:
    vals = median_sb[feature_label == lab]
    plt.figure()
    plt.hist(vals,
             range=[25, 29],
             bins=5,
             histtype='step',
             linewidth=1.5,
             label=str(lab))
    
    percentiles = np.percentile(vals, [25, 50, 75])
    print(percentiles, len(vals))

    plt.gca().invert_xaxis()
    plt.xlabel("Median Surface Brightness [mag/arcsec$^{2}$]")
    plt.ylabel("Number of Features")
    plt.title("Distribution of Tidal Feature Surface Brightnesses by Label")
    plt.legend(title="Label")
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.1666666666666">
# [27.0990785  27.47670323 27.79718706] 12
# <img src="data:image/png;base64,..." width="640.1666666666666">
# [27.70875752 28.06372758 28.41962831] 28
# <img src="data:image/png;base64,..." width="640.1666666666666">
# [26.98816771 27.30384072 28.44685914] 11
# <img src="data:image/png;base64,..." width="640.1666666666666">
# [26.33381701 28.56587604 28.97853669] 20
# <img src="data:image/png;base64,..." width="640.1666666666666">
# [26.79048331 27.14606804 27.50165278] 2
# <img src="data:image/png;base64,..." width="640.1666666666666">
# [26.76058275 27.45569335 28.40187318] 26

# %% [markdown]
# - **Summary statistics**
#   - For each class compute and record:
#     - sample size $n$,
#     - median and IQR (75th–25th percentile),
#
# - **Interpretation**
#   - Compare the medians: which feature types are generally brighter or fainter?
#   - Look at the IQRs: which classes show a wide range of surface brightnesses and which are more uniform?
#   - Consider the sample size $n$: rarer features may be intrinsically fainter or simply harder to detect.
#   - Reflect on detectability: faint features may be missing from your sample, biasing the observed distributions.
#   - Discuss how both abundance and detectability influence the conclusions you can draw about the physical properties and frequency of tidal features.

# %%
unique_labels = np.unique(feature_label)

plt.figure()
for lab in unique_labels:
    vals = median_sb[feature_label == lab]
    vals_sorted = np.sort(vals)
    cdf = np.arange(1, len(vals_sorted)+1) / len(vals_sorted)   
    plt.plot(vals_sorted, cdf, lw=1.5, label=str(lab))

plt.legend(title="Label")
plt.gca().invert_xaxis()
plt.xlabel("Median Surface Brightness [mag/arcsec$^{2}$]")
plt.ylabel("Cumulative Fraction")
plt.title("CDF of Tidal Feature Surface Brightness by Label")
plt.ylim(0, 1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.1666666666666">

# %%
unique_labels = np.unique(feature_label)

for lab in unique_labels:
    N = np.count_nonzero(feature_label == lab)
    percentiles = np.percentile(median_sb[feature_label == lab], [25, 50, 75])
    IQR = np.count_nonzero(feature_label == lab)
    print(lab, f'N = {N}', f'IQR = {percentiles[2] - percentiles[0]}', f'average={percentiles[1]}')
# Out:
# Merger Remnant N = 12 IQR = 0.6981085626706296 average=27.476703231745148
# Plume N = 28 IQR = 0.7108707900736952 average=28.06372758401138
# Shell N = 11 IQR = 1.4586914277064729 average=27.303840723081237
# Stellar Stream N = 20 IQR = 2.644719685535115 average=28.565876039835366
# Tidal Bridge N = 2 IQR = 0.7111694734486953 average=27.14606804240404
# Tidal Tail N = 26 IQR = 1.641290436531147 average=27.455693345460155

# %% [markdown]
# Finally, We'll examine a much deeper version of the image than the one used for labelling.
#
# - As before you can change the image stretch etc to better recover tidal features

# %%
FLUXMAG0 = 63095734448.0194 # counts to magnitudes
IMAGE_PSF = 1.0 / 0.2 / 2.355 # 1 arcsec FWHM PSF
IMAGE_SCALE = 0.2 # pixel size in arcsec
library_path = './library'

lib = GalaxyLibrary(library_path)

n_x = 5000
n_y = 5000

# create a mosaic of galaxies
canvas = lib.create_canvas((5000, 5000), n_objects=320, seed=1, z_min=0.08)
canvas = lib.create_canvas((5000, 5000), n_objects=110, seed=8, z_min=0., z_max=0.08)

canvas = lib.inject_specific(canvas, [('obj_00002_z0.05_904.h5', n_x//2-1800, n_y//2-1800),
                                      ('obj_00001_z0.05_658.h5', n_x//2+1000, n_y//2-1200),
                                      ('obj_00003_z0.05_658.h5', n_x//2+500, n_y//2),
                                      ('obj_00025_z0.05_791.h5', n_x//2-1350, n_y//2-1600),
                                      ('obj_00038_z0.05_658.h5', 700, 3000),
                                      ('obj_00019_z0.05_658.h5', 3500, 2500),
                                      ('obj_00013_z0.05_658.h5', 1000, 4500),
                                      ('obj_00135_z0.05_904.h5', 2000, 2000),
                                      ('obj_00036_z0.05_791.h5', 500, 2500),
                                      ('obj_00009_z0.05_904.h5', 3500, 3000),
                                      ('obj_00076_z0.05_658.h5', 3000, 3500),
                                      ('obj_00004_z0.05_904.h5', 4000, 3250)
                                      ], scale=4, flux_scale=0.8)


canvas_adu = canvas * FLUXMAG0

del canvas

# add a sky and stars
img_sky, bg_model, noise = lib.add_sky(canvas_adu,
            sky_mag=100.0,
            fluxmag0=FLUXMAG0,
            pixscale=IMAGE_SCALE,
            effective_gain=1000.,
            n_stars=100,
            star_mag_range=(18., 22.),
            psf_sigma=IMAGE_PSF,
            sb_noise_mag=35.0,
            seed=1)

fv = FitsViewer(img_sky)
# Out:
# <img src="data:image/png;base64,..." width="800">
# interactive(children=(Dropdown(description='stretch', options=('linear', 'log', 'sqrt', 'asinh'), value='linea…

# %% [markdown]
# This reveals numerous faint tidal features that were invisible in the shallower data, including:
#
# - Extremely diffuse galaxy outskirts
# - Numerous Very low-surface-brightness streams
# - Tidal features around lower-mass galaxies
#
# By comparing this deep view to the features you labelled, it becomes clear that many tidal structures remain undetectable in typical survey data:
#
# - The abundances measured in this exercise are lower limits.
# - Surface-brightness limits strongly bias which features can be detected.
# - Upcoming deeper surveys will likely uncover far more faint tidal debris than currently catalogued, but don't approach the depths necessary to recover complete samples of tidal features.
